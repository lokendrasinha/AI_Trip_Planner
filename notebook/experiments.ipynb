# %%
print("hello")
# Out:
# hello

# %%
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
llm.invoke("hi")
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={'reasoning_content': 'The user just says "hi". We need to respond friendly. No special instructions.'}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 72, 'total_tokens': 108, 'completion_time': 0.080642199, 'completion_tokens_details': {'reasoning_tokens': 18}, 'prompt_time': 0.013457181, 'prompt_tokens_details': None, 'queue_time': 0.083323367, 'total_time': 0.09409938}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_8a618bed98', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019dc3b5-5aa6-73e2-94d7-95d54555446d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 36, 'total_tokens': 108, 'output_token_details': {'reasoning': 18}})

# %%
from langchain.tools import tool

# %%
@tool
def multiply(a:int, b: int) -> int:
    """Multiplies two numbers."""
    return a * b

# %%
from langchain_core.tools import StructuredTool

# %%
class WeatherInput(BaseModel):
    city: str

# %%
def get_weather(city: str) -> str:
    """Fetches real-time weather data for a city."""
    # Imagine this function makes an API call to a weather service
    return f"The current weather in {city} is sunny with a temperature of 25°C."

# %%
weather_tool = StructuredTool.from_function(
    func = get_weather,
    name = "get_weather",
    description="Fetches real-time weather data for a city",
    args_schema=WeatherInput,       
)
